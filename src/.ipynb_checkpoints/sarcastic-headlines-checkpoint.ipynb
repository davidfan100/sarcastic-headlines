# %%
import pandas as pd
from collections import defaultdict

# %%
data_pts = pd.read_json('../data/Sarcasm_Headlines_Dataset.json', lines = True)

data_pts['is_sarcastic']
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
# 5        0
# 6        0
# 7        0
# 8        1
# 9        0
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       1
# 16       1
# 17       1
# 18       0
# 19       0
# 20       1
# 21       1
# 22       0
# 23       0
# 24       0
# 25       0
# 26       0
# 27       1
# 28       1
# 29       0
#         ..
# 26679    0
# 26680    1
# 26681    0
# 26682    0
# 26683    1
# 26684    1
# 26685    1
# 26686    1
# 26687    0
# 26688    1
# 26689    0
# 26690    0
# 26691    1
# 26692    0
# 26693    1
# 26694    1
# 26695    1
# 26696    0
# 26697    0
# 26698    0
# 26699    0
# 26700    0
# 26701    0
# 26702    1
# 26703    1
# 26704    0
# 26705    0
# 26706    0
# 26707    0
# 26708    0
# Name: is_sarcastic, Length: 26709, dtype: int64

# %%
headline_freq_counter = defaultdict(int)

for index, row in data_pts.iterrows():
    
    if bool(row['is_sarcastic']) == True:
        
        words = row['headline'].split(' ')
        for word in words:
            headline_freq_counter[word] += 1
# item[1] is based on the dict, so that is the num value
sorted(headline_freq_counter.items(), key = lambda item: item[1], reverse=True)
# Out:
# [('to', 4141),
#  ('of', 3131),
#  ('in', 1753),
#  ('for', 1416),
#  ('on', 1053),
#  ('man', 1021),
#  ('with', 854),
#  ('new', 821),
#  ('the', 584),
#  ('by', 580),
#  ('from', 560),
#  ('at', 545),
#  ('a', 518),
#  ('area', 477),
#  ('out', 461),
#  ('up', 424),
#  ('about', 407),
#  ('after', 381),
#  ('he', 379),
#  ('as', 376),
#  ('it', 365),
#  ('report:', 360),
#  ('be', 349),
#  ('into', 344),
#  ('not', 343),
#  ('just', 338),
#  ('has', 333),
#  ('that', 316),
#  ('woman', 290),
#  ('who', 279),
#  ('all', 267),
#  ('and', 254),
#  ('one', 253),
#  ('more', 243),
#  ('his', 227),
#  ('time', 213),
#  ('have', 211),
#  ('now', 209),
#  ('still', 208),
#  ('day', 207),
#  ('off', 201),
#  ('trump', 200),
#  ('nation', 193),
#  ('this', 192),
#  ('like', 187),
#  ('u.s.', 187),
#  ('get', 187),
#  ('will', 186),
#  ('can', 186),
#  ('you', 182),
#  ('no', 181),
#  ('only', 176),
#  ('finds', 173),
#  ('is', 172),
#  ('back', 171),
#  ('first', 169),
# ...
